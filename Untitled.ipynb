# %%
from dolfin import *

# Test for PETSc and SLEPc
if not has_linear_algebra_backend("PETSc"):
    print("DOLFIN has not been configured with PETSc. Exiting.")
    exit()

# %%
import matplotlib.pyplot as plt

# %%
if not has_slepc():
    print( "DOLFIN has not been configured with SLEPc. Exiting.")
    exit()

# %%
# Define mesh, function space
mesh = Mesh("box_with_dent.xml.gz")
V = FunctionSpace(mesh, "Lagrange", 1)

# Define basis and bilinear form
u = TrialFunction(V)
v = TestFunction(V)
a = dot(grad(u), grad(v))*dx

# Assemble stiffness form
A = PETScMatrix()
assemble(a, tensor=A)

# Create eigensolver
eigensolver = SLEPcEigenSolver(A)

# Compute all eigenvalues of A x = \lambda x
print("Computing eigenvalues. This can take a minute.")
eigensolver.solve()

# Extract largest (first) eigenpair
r, c, rx, cx = eigensolver.get_eigenpair(0)

print("Largest eigenvalue: ", r)

# Initialize function and assign eigenvector
u = Function(V)
u.vector()[:] = rx

# Plot eigenfunction
u
# Out:
# Computing eigenvalues. This can take a minute.
# Largest eigenvalue:  10.027944485404854
# Coefficient(FunctionSpace(Mesh(VectorElement(FiniteElement('Lagrange', tetrahedron, 1), dim=3), 20), FiniteElement('Lagrange', tetrahedron, 1)), 34)

# %%
for _ in range(eigensolver.get_number_converged()):
    print(f"Real part of eigenpair: {eigensolver.get_eigenpair(_)[0]}")
    print(f"Complex part of eigenpair: {eigensolver.get_eigenpair(_)[1]}")
# Out:
# Real part of eigenpair: 10.027944485404854
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 9.72539999750165
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 9.60490603705371
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 9.429456279476938
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 9.355664178731146
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 8.969941125809838
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 8.921088205862853
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 8.767207946854988
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 8.525062759970428
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 8.455331541958108
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 8.241400627324802
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 8.224241685454961
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 8.014880481433009
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 7.892467673372726
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 7.767089298152215
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 7.7253298501492145
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 7.630038434457232
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 7.428491685443237
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 7.311380083586297
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 7.262503247980369
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 7.202616570514976
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 7.101036206636205
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.926376693103083
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.913135618252387
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.780088458625043
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.692149313923099
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.65573147410458
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.606386350918238
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.595799790799808
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.412269501270955
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.345593362032943
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.33057573865127
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.2637315183187
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.151517261776535
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.0703901840086525
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.045147169715002
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 6.000906749039152
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 5.817136781152447
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 5.645991731161872
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 5.552218032310245
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 5.4774601206781615
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 5.29103306853618
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 5.249795238209583
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 5.045651366373679
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.99777065324822
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.864818614961206
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.827041807339448
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.692379955681379
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.6067423032445
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.602505625234352
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.5604209356764
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.5156960515303055
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.478299832471101
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.46305730529802
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.452497063176558
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.328030249458507
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.277996325261062
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.252511350307784
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.235585017211656
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.17721451459808
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.1384203796192525
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.128804450732606
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.10338911842065
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.062902855665854
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.0144745674540445
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 4.012220564310408
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.972581907392773
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.9684687423571527
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.9641587198617856
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.935386105795243
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.92939829309374
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.9046272884983075
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.8983737601005215
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.8807100445354052
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.848432318299322
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.8382316126839306
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.80493253329178
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.7751625463133984
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.734813605151349
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.731314282595972
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.7148190970055692
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.713513056560042
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.684643828954127
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.665091864747045
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.642253848758298
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.6291807775265945
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.62032542106261
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.577682855363567
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.5512685836169755
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.54483735077242
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.4853837764185274
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.478155788839715
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3.4562488541822463
# Complex part of eigenpair: 0.0
# Real part of eigenpair: 3